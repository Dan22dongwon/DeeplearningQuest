# %% [markdown]
# <a href="https://colab.research.google.com/github/Dan22dongwon/DeeplearningQuest/blob/main/1_%EC%BB%B4%ED%93%A8%ED%84%B0_%EB%B9%84%EC%A0%84_%ED%83%9C%EC%8A%A4%ED%81%AC_%E2%80%9C%EC%83%81%EC%83%81%E2%80%9D%ED%95%B4_%EB%B3%B4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 컴퓨터 비전 태스크 “상상”해 보기
#
# 안녕하세요! 🙋
#
# '딥러닝으로 시작하는 컴퓨터 비전'을 배우러 오신 여러분을 진심으로 환영합니다! 🥳
#
# 앞으로 10시간동안 딥러닝부터 시작하여 컴퓨터 비전에서 다루는 다양한 개념을 배우고, 간단한 실습을 할 예정입니다. 개념 이해가 다소 어려울 수 있지만 '딥러닝으로 시작하는 컴퓨터 비전'을 끝까지 들으시고 충실히 실습 및 프로젝트를 진행하시면 여러분들은 컴퓨터 비전 개발자가 되는 첫 걸음을 훌륭하게 내딛으실 것입니다.
#
# ## '딥러닝으로 시작하는 컴퓨터 비전'을 모두 학습하면 할 수 있는 것은?
# '딥러닝으로 시작하는 컴퓨터 비전'을 충실히 학습하면 아래의 프로젝트를 수행할 수 있습니다. 어떤 프로젝트가 있는지 알아볼까요?
#
#
# ## 프로젝트 1: Image Classification
# 프로젝트 1에서는 VGG16 모델을 사용하여 개와 고양이 사진을 분류해 봅니다. 여러분들은 이 프로젝트에서 VGG16 모델을 직접 구현하고 성능을 확인해 볼 거에요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 모델의 정확도는 아래 이미지와 같이 정확도(Accuracy)와 손실(Loss) 그래프를 그려서 확인합니다. 예시로 주어진 코드의 성능이 그리 좋지 않기 때문에 여러분들은 콘텐츠에서 다룬 다양한 방법을 사용하여 모델의 성능을 높여보는 것까지 해보시게 될 거에요.
#
# ![image.png](data:image/png;base64,...)
#
#
# ### 프로젝트 2: Object Detection
# 프로젝트 2에서는 오픈 소스로 공개된 모델을 사용하여 Object Detection을 해봅니다. 다양한 모델 중 우리는 Faster RCNN을 사용합니다.
#
# 여러분들은 이 프로젝트에서 2가지 문제를 해결하셔야 합니다. 첫번째는 LMS에서 제공하는 이미지 외의 다른 이미지를 가져와서 Object Detection을 해보는 것이고, 두번째는 다양한 pre-trained model을 사용하여 결과를 테스트해보는 것입니다..
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 콘텐츠 구성 및 학습 가이드
# 이번에는 '딥러닝으로 시작하는 컴퓨터 비전'이 어떻게 구성되어 있는지와 어떻게 학습할지를 알아보겠습니다.
#
# ## 콘텐츠 구성
# '딥러닝으로 시작하는 컴퓨터 비전'은 총 10개의 노드로 구성되어 있습니다. 1~9번 노드는 이론이고, 10번 노드는 프로젝트입니다.
#
#
# ### 이론
#
# 1. 컴퓨터 비전 태스트 '상상'해 보기
# 2. 다층 퍼셉트론(Multi-Layer Perceptron) 구조 복습하기
# 3. CNN 하나씩 이해하기 (1) 1-Channel Convolution
# 4. CNN 하나씩 이해하기 (2) 3-Channel Convolution
# 5. CNN 하나씩 이해하기 (3) Pooling
# 6. 심화된 CNN 구조
# 7. Transfer Learning 이해하기
# 8. Object Detection
# 9. Segmentation
#
# 프로젝트
#
# 10. Computer Vision Project
#
# 1~9번 노드는 영상으로 이론을 설명하고, 설명한 내용을 코드를 통해 확인합니다. 뿐만 아니라 학습한 내용을 점검하고 복습할 수 있는 이론 퀴즈와 코드 퀴즈, 그리고 배운 내용을 정리하는 마무리 퀴즈가 있습니다.
#
# 10번 노드는 Image Classification과 Object Detection과 관련된 2개의 프로젝트가 제공됩니다. 프로젝트에 대한 상세한 내용은 아래에서 다루겠습니다.

# %% [markdown]
# ### 콘텐츠 상세 구조
# '딥러닝으로 시작하는 컴퓨터 비전'은 영상에서 모든 내용을 설명하지 않습니다. 영상에서는 여러분들이 꼭 알아야 하는 핵심만 설명하기 때문에 추가로 제공하는 텍스트와 코드를 꼼꼼히 학습하시기 바랍니다. 여러분들의 학습을 돕기 위해 다양한 퀴즈도 추가하였으니 빠짐없이 퀴즈를 풀어보시기 바랍니다.
#
# 영상에서 언급한 내용은 퀴즈를 해결하면서 정리할 수 있도록 하였습니다. 그 외에 LMS에는 영상에서 설명하지 않는 텍스트나 코드를 설명하고, 학습한 내용을 정리하는 퀴즈가 있습니다.
#
# 노드 마지막에는 배운 내용을 총정리하는 종합 퀴즈가 있습니다.
#
# - 영상
# - 텍스트와 코드
# - 퀴즈(이론 및 실습)
# - 종합 퀴즈
#
# ## 학습 가이드
# '딥러닝으로 시작하는 컴퓨터 비전'을 학습하실 때에는
# - 1) 영상을 반복 시청하여 영상에서 언급한 내용을 충분히 습득하고
# - 2) LMS를 통해 영상에서 설명한 내용을 복습하고 실습해 보시면 됩니다.
#
# 텍스트와 코드만 주어진 부분은 텍스트와 코드를 꼼꼼히 읽어 보세요.
#
# 각 코드가 어떤 역할을 하는지에 대한 설명은 적어두었으나 여러분의 성장을 위해 한줄 한줄 설명을 구체적으로 적지는 않았습니다. 낯선 명령어 또는 이해가 되지 않는 코드가 있다면 검색을 통해 그 의미를 찾아보거나 print()를 사용하여 각 코드가 어떤 결과를 출력하는지 알아보세요.
#
# 퀴즈는 노드에서 학습한 내용을 여러분들이 숙지하셨으면 하는 바람으로 넣은 것이니 바로 [예시답안]을 클릭하지 말고 여러분이 직접 생각하고 정리한 답을 적어보세요. 누가 점검하지 않더라도 퀴즈에 열심히 고민한 답을 적으시다보면 노드를 끝낼 쯤에는 성장한 여러분의 모습을 발견하시게 될거에요!
#
# 프로젝트의 경우, 콘텐츠를 제대로 학습하셨다면 충분히 해결할 수 있는 프로젝트이기 때문에 프로젝트의 답안은 따로 제공하지 않았습니다. 답안을 제공하지 않은 또다른 이유는 프로젝트의 정답이 존재하지 않기 때문입니다. 창의력을 발휘하여 다양한 방법을 사용해 여러분만의 프로젝트를 완성해 보세요. 👍
#
# 그럼 '딥러닝으로 시작하는 컴퓨터 비전' 학습을 시작해 볼까요? 🏃

# %% [markdown]
# ## 1-2. 들어가며
# 안녕하세요!
#
# 컴퓨터 비전 태스트를 "상상"해보러 오신 여러분을 환영합니다. 지금부터 컴퓨터가 이미지를 인식하는 방법은 인간의 방법과 무엇이 다른지, 이미지 속 정보가 가지고 있는 특징이 무엇인지, 그리고 컴퓨터 비전 태스크에는 무엇이 있는지 알아봅시다.
#
# 본격적으로 학습에 들어가기에 앞서 간단한 아이스브레이킹을 해 볼까요?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [아이스브레이킹]여러분 위에 있는 이미지에는 어떤 동물이 숨어 있는거 같나요?
#
# 고양이
#
#
# ## 학습 내용
# - 1-3. 이미지 "데이터" 이해하기
#    - 인간이 이미지를 인식하는 방법과 컴퓨터가 이미지를 인식하는 방법을 알아보고, 차이점을 알아봅니다.
# - 1-4. 이미지 내의 정보 찾아보기
#    - 데이터는 정보일까요? 이미지 내의 정보의 특징을 알아봅니다.
# - 1-5. 컴퓨터 비전의 다양한 태스크
#    - 컴퓨터 비전의 대표적인 태스크인 Classification, Object Detection, Segmentation을 알아봅니다.

# %% [markdown]
# ### 학습 목표
# - 이미지 데이터가 가진 특징을 설명할 수 있습니다.
# - 컴퓨터 비전 태스크들의 각각의 목표와 차이점을 설명할 수 있습니다.

# %% [markdown]
# ### 1-3 이미지 데이터 이해하기
#
# Q. 인간이 이미지를 인식하는 방법과 컴퓨터가 이미지를 인식하는 방법의 차이를 설명해 보세요.
#
# 인간이 이미지를 인식하는 방법
# 1. 빛이 사물에 반사 되어 반사된 빛이 눈으로 들어 옴
# 2. 각각의 시각 세표가 반사된 빛을, 색의 RGB를 인식 하여 뇌로 신호를 전달함
# 3. 빛의 신호가 전기 신호로 변환 되어 뇌로 전달 되고 뇌에서 이미지가 출력됨
#
# 컴퓨터 이미지 인식 하는 방법
# 1. 이미지 파일이 3차원의 픽셀에 저장 하고 Depth로 RGB 값이 입력된 숫자 덩어리를 만들고 컴퓨터에 입력
# 2. 컴퓨터의 연산 장치를 통해 이미지를 판단 하고 결과를 출력

# %% [markdown]
# ### 1-4. 이미지 내의 정보 찾아보기
#  1. 데이터 = 정보?
#  - 이미지 데이터의 픽셀 하나에 담긴 숫자 자체에는 아무런 정보(페턴)가 없습니다
#  그저, 숫자 덩어리 입니다
#
#  2. 이미지 내의 정보
#  - 색 정보
#  - 형태
#  - 질감
#
#  3. 이미지 속 정보의 특징
#  - 이미지 데이터 안의 정보는 하나의 픽셀 그 자체가 아닌 주변의 여러개의 픽셀과의 관계를 통해서 드러 납니다

# %% [markdown]
# ## 1-5. 컴퓨터 비전의 다양한 태스크
#
# 이미지, 영상
#
# 1. Classification
# - Single object
#   - Classification
#   - Classification+Localization
# - Multiple objects
#   - Object Detevtion
#   - Instance Segmentation

# %% [markdown]
# Q. 컴퓨터 비전의 각 태스크는 어떻게 구분할 수 있나요?
#
# 컴퓨터 비전의 태스크는 Single Object인지 Multiple Object인지에 따라 구분할 수 있습니다. Single Object를 다루는 태스크에는 Classification과 Localization이 있고, Multiple Object를 다루는 태스크는 Object Detection과 Instance Segmentation이 있습니다.
#
# Q. Classification과 Localization를 설명해 보세요.
#
# - Classification: 1개의 object의 class를 예측하는 태스크입니다.
# - Localization: object의 위치를 찾아내는 태스크로, Bounding Box를 통해 위치를 지정합니다.
#
# Q. Object Detection을 설명해 보세요.
#
# Object Detection는 Bounding Box로 위치를 지정하고, 각 Bounding Box 안의 obejct를 classification을 하는 것입니다. Object Detection = Bounding Box Regression (Localization) + Multi-Labeled Classification
#
# Q. Segmentation을 설명해 보세요.
#
# Segmentation은 픽셀 수준에서의 의미를 찾는 태스크입니다. Segmentation은 이미지를 픽셀 단위로 분해하고 픽셀의 class를 분류하는 Semantic Segmentation와 픽셀이 어떤 개별 객체(개체, Instance)로 구분되는지 분류하는 Instance Segmentation로 구분할 수 있습니다.
#
#
# Q. 이미지 데이터를 분석한다는 의미는 무엇인가요?
#
# 이미지 데이터를 분석한다는 의미는 3차원의 숫자 덩어리를 입력으로 받아 그 안에 숨겨진 패턴을 찾는다는 뜻입니다.
#
# Q. 이미지의 픽셀이 가진 의미는 무엇에 의해 결정되나요?
#
# 이미지의 픽셀의 의미는 주변 픽셀 간의 유사성(같다 또는 다르다)에 의해 결정됩니다.
#
#
# 종합 퀴즈의 난도는 어떠셨나요?
#
# 학습을 충실히 하셨다면 쉽게 해결하셨을 것이라 생각합니다. 혹시라도 답을 맞추지 못하셨다면 다시 한번 배웠던 내용을 복습해 보세요.
#
# 지금까지 수고 많이 하셨습니다! 🥳
